# %%
'''
W9A1
Viết hàm merge hai danh sách đã sắp xếp mà không dùng bất cứ
thuật toán sắp xếp nào 
'''
def merge(list1,list2):
    i, j = 0, 0
    merged = []
    while i < len(list1) and j < len(list2):
        if list1[i] <list2[j]:
            merged.append(list1[i])
            i += 1
        else:
            merged.append(list2[j])
            j += 1
    merged.extend(list1[i:])
    merged.extend(list2[j:])
    return merged
list1 = list(map(int,input().split()))
list2 = list(map(int,input().split()))
print(merge(list1,list2))
# Out:
#  0 1 1 1 1 1 2 2 3 4 6 7 8 9
#  1 2 3 4 5
# [0, 1, 1, 1, 1, 1, 1, 2, 2, 2, 3, 3, 4, 4, 5, 6, 7, 8, 9]

# %%
'''
W9A2
Cho ma trận hai chiều nxm có các phần tử được sắp xếp trên
dòng tăng dần và trên cột tăng dần, hãy tìm số lớn thứ k (k < nxm) với thuật toán tốt nhất có thể
'''
